# %% [markdown]
# <a href="https://colab.research.google.com/github/jatinvijayvargiya26/assingment1/blob/main/Week5_Jatin_Vijayvargiya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Deep Learning Text Generation Learning Project
# ## Text Generation using **Vanilla RNN, LSTM, and GRU**
#
# This notebook is built for **students and beginners** to understand how sequence models learn:
# - grammar
# - sentence flow
# - contextual dependencies
# - next-word prediction
# - text generation
#
# 🎯 **Goal:** Compare **Simple RNN vs LSTM vs GRU** on the same text corpus and understand why gated architectures perform better.

# %% [markdown]
# # 🧠 Problem Statement
# Design and implement a DL model capable of learning the underlying structure, grammar, and contextual dependencies of a given text corpus to generate coherent and meaningful text sequences using:
#
# 1. **Vanilla RNN**
# 2. **LSTM**
# 3. **GRU**
#
# Then compare:
# - training loss
# - generated text quality
# - memory handling
# - long-term dependency learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import numpy as np
import matplotlib.pyplot as plt
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 📥 Load Text Corpus
# We use a **small built-in sample corpus** so students can run this quickly.
# You can later replace it with:
# - Shakespeare text
# - song lyrics
# - chatbot data
# - story paragraphs
# - custom PDF extracted text

# %%
corpus = '''
deep learning is transforming artificial intelligence
recurrent neural networks are useful for sequential data
lstm helps remember long term dependencies
gru is faster and simpler than lstm
text generation models predict the next word
deep learning models can generate meaningful sentences
'''
print(corpus)
# Out:
# deep learning is transforming artificial intelligence
# recurrent neural networks are useful for sequential data
# lstm helps remember long term dependencies
# gru is faster and simpler than lstm
# text generation models predict the next word
# deep learning models can generate meaningful sentences

# %% [markdown]
# # 🔤 Tokenization & Sequence Creation
# We convert text into integer tokens and create **n-gram style sequences**
# for next-word prediction.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])

total_words = len(tokenizer.word_index) + 1

print("Vocabulary Size:", total_words)

# Create empty list
input_sequences = []

for line in corpus.split('\n'):

    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

max_len = max(len(seq) for seq in input_sequences)

input_sequences = pad_sequences(
    input_sequences,
    maxlen=max_len,
    padding='pre'
)

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

print("X Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# Vocabulary Size: 43
# X Shape: (46, 7)
# y Shape: (46,)

# %% [markdown]
# # 🧠 Model 1: Vanilla RNN
# This is the baseline sequential model.
# It struggles with long-term dependencies because of vanishing gradients.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

def build_rnn():

    model = Sequential([
        Embedding(total_words, 64, input_length=max_len-1),
        SimpleRNN(128),
        Dense(total_words, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
rnn_model = build_rnn()

rnn_history = rnn_model.fit(
    X,
    y,
    epochs=150,
    verbose=1
)
# Out:
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.0217 - loss: 3.7577
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0652 - loss: 3.6758
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1522 - loss: 3.6015
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1739 - loss: 3.5197
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1304 - loss: 3.4425
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1087 - loss: 3.3789
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1739 - loss: 3.3190
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2174 - loss: 3.2563
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2826 - loss: 3.1794
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3261 - loss: 3.0928
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3696 - loss: 3.0161
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3696 - loss: 2.9290
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3696 - loss: 2.8397
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3913 - loss: 2.7386
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3913 - loss: 2.6395
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3696 - loss: 2.5511
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3913 - loss: 2.4569
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3913 - loss: 2.3683
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4130 - loss: 2.2838
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5217 - loss: 2.2033
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5435 - loss: 2.0950
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5652 - loss: 2.0024
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5870 - loss: 1.9291
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6087 - loss: 1.8433
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6522 - loss: 1.7550
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7391 - loss: 1.6774
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7391 - loss: 1.5951
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7609 - loss: 1.5199
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7609 - loss: 1.4473
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7174 - loss: 1.3765
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7609 - loss: 1.3075
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7826 - loss: 1.2490
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7826 - loss: 1.1838
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7826 - loss: 1.1201
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8043 - loss: 1.0696
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8043 - loss: 1.0122
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8043 - loss: 0.9666
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8043 - loss: 0.9219
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8043 - loss: 0.8731
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8261 - loss: 0.8299
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8261 - loss: 0.7923
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8478 - loss: 0.7551
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8696 - loss: 0.7194
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8913 - loss: 0.6852
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8913 - loss: 0.6540
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8913 - loss: 0.6217
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8913 - loss: 0.5960
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8913 - loss: 0.5675
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9130 - loss: 0.5433
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9130 - loss: 0.5196
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9130 - loss: 0.4984
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9130 - loss: 0.4779
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9130 - loss: 0.4568
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9348 - loss: 0.4384
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9565 - loss: 0.4241
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9565 - loss: 0.4069
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9565 - loss: 0.3886
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9565 - loss: 0.3717
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9565 - loss: 0.3587
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9348 - loss: 0.3461
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9348 - loss: 0.3318
# Epoch 62/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9565 - loss: 0.3208
# Epoch 63/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9783 - loss: 0.3066
# Epoch 64/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9783 - loss: 0.2929
# Epoch 65/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.2839
# Epoch 66/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.2729
# Epoch 67/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9783 - loss: 0.2623
# Epoch 68/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.2525
# Epoch 69/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.2432
# Epoch 70/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.2354
# Epoch 71/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.2270
# Epoch 72/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9783 - loss: 0.2190
# Epoch 73/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.2106
# Epoch 74/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9783 - loss: 0.2022
# Epoch 75/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1950
# Epoch 76/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9565 - loss: 0.1929
# Epoch 77/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9783 - loss: 0.1847
# Epoch 78/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.1774
# Epoch 79/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1706
# Epoch 80/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1662
# Epoch 81/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.1599
# Epoch 82/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.1560
# Epoch 83/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.1509
# Epoch 84/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9783 - loss: 0.1528
# Epoch 85/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.1440
# Epoch 86/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9565 - loss: 0.1420
# Epoch 87/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1371
# Epoch 88/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1326
# Epoch 89/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1261
# Epoch 90/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9783 - loss: 0.1232
# Epoch 91/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1205
# Epoch 92/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1178
# Epoch 93/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.1130
# Epoch 94/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9783 - loss: 0.1109
# Epoch 95/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9783 - loss: 0.1096
# Epoch 96/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1090
# Epoch 97/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1077
# Epoch 98/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.1047
# Epoch 99/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9783 - loss: 0.1003
# Epoch 100/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9783 - loss: 0.0988
# Epoch 101/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9783 - loss: 0.0969
# Epoch 102/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9783 - loss: 0.0936
# Epoch 103/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9783 - loss: 0.0925
# Epoch 104/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9783 - loss: 0.0912
# Epoch 105/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9783 - loss: 0.0896
# Epoch 106/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9783 - loss: 0.0861
# Epoch 107/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9783 - loss: 0.0838
# Epoch 108/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9783 - loss: 0.0854
# Epoch 109/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9783 - loss: 0.0866
# Epoch 110/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9783 - loss: 0.0863
# Epoch 111/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9783 - loss: 0.0839
# Epoch 112/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9783 - loss: 0.0804
# Epoch 113/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0770
# Epoch 114/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.0757
# Epoch 115/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9783 - loss: 0.0761
# Epoch 116/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9783 - loss: 0.0753
# Epoch 117/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9783 - loss: 0.0739
# Epoch 118/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0734
# Epoch 119/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.0708
# Epoch 120/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0701
# Epoch 121/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9783 - loss: 0.0698
# Epoch 122/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9783 - loss: 0.0696
# Epoch 123/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.0671
# Epoch 124/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.0658
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9783 - loss: 0.0652
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.0647
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0653
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9783 - loss: 0.0656
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9783 - loss: 0.0659
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9783 - loss: 0.0656
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9783 - loss: 0.0613
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9565 - loss: 0.0625
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0600
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.0621
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.0601
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0585
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9783 - loss: 0.0602
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9783 - loss: 0.0576
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9783 - loss: 0.0568
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9783 - loss: 0.0563
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9783 - loss: 0.0556
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9783 - loss: 0.0556
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9783 - loss: 0.0596
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9783 - loss: 0.0569
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9783 - loss: 0.0548
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9783 - loss: 0.0535
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9783 - loss: 0.0542
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9783 - loss: 0.0576
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9783 - loss: 0.0553
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9783 - loss: 0.0529

# %% [markdown]
# # 🔒 Model 2: LSTM
# LSTM uses **input, forget, and output gates**
# to preserve long-term memory.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

def build_lstm():

    model = Sequential([
        Embedding(total_words, 64, input_length=max_len-1),
        LSTM(128),
        Dense(total_words, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
print("\nTraining LSTM...\n")

lstm_model = build_lstm()

lstm_history = lstm_model.fit(
    X,
    y,
    epochs=150,
    verbose=1
)

print("\nLSTM Training Complete\n")

# %% [markdown]
# # ⚡ Model 3: GRU
# GRU uses **reset + update gates**.
# It is computationally faster than LSTM and often gives similar results.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

def build_gru():

    model = Sequential([
        Embedding(total_words, 64, input_length=max_len-1),
        GRU(128),
        Dense(total_words, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
print("\nTraining GRU...\n")

gru_model = build_gru()

gru_history = gru_model.fit(
    X,
    y,
    epochs=150,
    verbose=1
)

print("\nGRU Training Complete\n")

# %% [markdown]
# ## 📉 Compare Training Loss

# %%
plt.figure(figsize=(10,4))
plt.plot(rnn_history.history['loss'], label='RNN')
plt.plot(lstm_history.history['loss'], label='LSTM')
plt.plot(gru_history.history['loss'], label='GRU')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Comparison")
plt.legend()
plt.show()
plt.figure(figsize=(10,5))

plt.plot(rnn_history.history['accuracy'], label='RNN')
plt.plot(lstm_history.history['accuracy'], label='LSTM')
plt.plot(gru_history.history['accuracy'], label='GRU')

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy Comparison")
plt.legend()
plt.show()

# %% [markdown]
# # ✍️ Text Generation Function
# This function predicts the next word repeatedly to generate a sentence.

# %%
def generate_text(model, seed_text, next_words=8):

    for _ in range(next_words):

        token_list = tokenizer.texts_to_sequences([seed_text])[0]

        token_list = pad_sequences(
            [token_list],
            maxlen=max_len-1,
            padding='pre'
        )

        predicted = np.argmax(
            model.predict(token_list, verbose=0),
            axis=-1
        )[0]

        output_word = ""

        for word, index in tokenizer.word_index.items():

            if index == predicted:
                output_word = word
                break

        seed_text += " " + output_word

    return seed_text

# %% [markdown]
# ## 🧪 Generate Text Samples

# %%
print("RNN :", generate_text(rnn_model, "deep learning", 5))
print("LSTM:", generate_text(lstm_model, "deep learning", 5))
print("GRU :", generate_text(gru_model, "deep learning", 5))
# Out:
# RNN : deep learning models can generate meaningful sentences
# LSTM: deep learning is transforming artificial intelligence intelligence
# GRU : deep learning is transforming artificial intelligence intelligence

# %% [markdown]
# # 📚 Student Learning Tasks
# ### ✅ Beginner Tasks
# 1. Replace corpus with your own paragraph
# 2. Increase embedding dimension
# 3. Increase epochs to 200
# 4. Change hidden units 64 → 128
# 5. Generate 10 words instead of 5

# %% [markdown]
# # ✅ Conclusion
# - **Vanilla RNN** learns short patterns but struggles with memory
# - **LSTM** captures long-range grammar dependencies better
# - **GRU** gives similar performance with fewer gates and faster training
# - This notebook helps students understand **sequence modeling mathematically and practically**
